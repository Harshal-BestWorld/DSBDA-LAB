# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset = sns.load_dataset('titanic')
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.displot(titanic['age'], bins=10, kde=True)
plt.title('Distribution of Age for Titanic Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.displot(titanic['age'], bins=10, kde=False)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.jointplot(x='age', y='fare', data=titanic, kind='scatter')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.jointplot(x='age', y='fare', data=titanic, kind='hex')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.rugplot(titanic['fare'])

plt.title('Rug Plot of Fare for Titanic Passengers')
plt.xlabel('Fare')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.barplot(x='sex', y='age', data=titanic)

plt.title('Average Age of Passengers by Sex on the Titanic')
plt.xlabel('Sex')
plt.ylabel('Average Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='sex', data=titanic)

plt.title('Count of Passengers by Sex on the Titanic')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='sex', y='age', data=titanic)

plt.title('Age Distribution by Sex on the Titanic')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='sex', y='age', data=titanic, hue='survived')

plt.title('Age Distribution by Sex and Survival Status on the Titanic')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot(x='sex', y='age', data=titanic)

plt.title('Age Distribution by Sex on the Titanic')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot(x='sex', y='age', data=titanic,hue='survived')

plt.title('Age Distribution by Sex on the Titanic')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.stripplot(x='sex', y='age', data=titanic, jitter=False)

plt.title('Age Distribution by Sex on the Titanic (No Jitter)')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.stripplot(x='sex', y='age', data=titanic, jitter=True)

plt.title('Age Distribution by Sex on the Titanic - Jitter')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.stripplot(x='sex', y='age', data=titanic, jitter=True,hue='survived')

plt.title('Age Distribution by Sex on the Titanic - Jitter')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.swarmplot(x='sex', y='age', data=titanic)

plt.title('Age Distribution by Sex on the Titanic')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 7.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.swarmplot(x='sex', y='age', data=titanic,hue='survived')

plt.title('Age Distribution by Sex on the Titanic')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 7.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 7.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset = sns.load_dataset('titanic')
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dataset.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
corr = dataset.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr = dataset.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>
